# %% [markdown]
# # Web Mining Menggunakan Trafilatura
#
# ## Pengumpulan Data Artikel Wikipedia
#
# Pada praktikum ini dilakukan proses pengumpulan data dari Wikipedia menggunakan teknik web mining. Data yang dikumpulkan berupa 200 artikel dari Wikipedia.
#
# Proses pengumpulan data dilakukan menggunakan Python, requests, dan Trafilatura. Setiap artikel akan diekstraksi menjadi data terstruktur yang terdiri dari judul, URL, teks artikel, dan jumlah kata.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.5.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/PPW/envwebmining/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspaces/PPW/envwebmining/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 39.2 MB/s  0:00:00ta 0:00:01
# Downloading numpy-2.5.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 43.6 MB/s  0:00:00s eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# Successfully installed numpy-2.5.3 pandas-3.0.5
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: /workspaces/PPW/envwebmining/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import trafilatura
import pandas as pd
import time
import re

print("Library berhasil diimpor")
# Out:
# Library berhasil diimpor

# %% [markdown]
# ## 1. Sumber Data
#
# Sumber data yang digunakan dalam praktikum ini adalah Wikipedia Bahasa Indonesia.
#
# Wikipedia digunakan sebagai sumber data karena artikel dapat diakses secara bebas melalui internet. Data yang dikumpulkan berupa artikel Wikipedia yang diperoleh melalui API Wikipedia.
#
# Pada praktikum ini akan dikumpulkan sebanyak 200 artikel. Setiap artikel akan memiliki informasi berupa judul, URL, isi teks, dan jumlah kata.

# %%
api_url = "https://id.wikipedia.org/w/api.php"

params = {
    "action": "query",
    "list": "search",
    "srsearch": "teknologi",
    "srnamespace": 0,
    "srlimit": 200,
    "format": "json"
}

headers = {
    "User-Agent": "WebMiningStudent/1.0 (educational project)"
}

response = requests.get(
    api_url,
    params=params,
    headers=headers,
    timeout=30
)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
data = response.json()

hasil_pencarian = data["query"]["search"]

print("Jumlah artikel ditemukan:", len(hasil_pencarian))
# Out:
# Jumlah artikel ditemukan: 200

# %%
hasil_data = []

headers = {
    "User-Agent": "WebMiningStudent/1.0 (educational project)"
}

print("Persiapan ekstraksi selesai")
# Out:
# Persiapan ekstraksi selesai

# %%
api_url = "https://id.wikipedia.org/w/api.php"

params = {
    "action": "query",
    "list": "search",
    "srsearch": "teknologi",
    "srnamespace": 0,
    "srlimit": 200,
    "format": "json"
}

headers = {
    "User-Agent": "WebMiningStudent/1.0 (educational project)"
}

response = requests.get(
    api_url,
    params=params,
    headers=headers,
    timeout=30
)

print("Status Code:", response.status_code)

data = response.json()
hasil_pencarian = data["query"]["search"]

print("Jumlah artikel ditemukan:", len(hasil_pencarian))
# Out:
# Status Code: 200
# Jumlah artikel ditemukan: 200

# %%
daftar_url = []

for item in hasil_pencarian:
    judul = item["title"]
    url = "https://id.wikipedia.org/wiki/" + judul.replace(" ", "_")
    
    daftar_url.append({
        "judul": judul,
        "url": url
    })

print("Jumlah URL:", len(daftar_url))
# Out:
# Jumlah URL: 200

# %%
hasil_data = []

print("Mulai proses ekstraksi...")
# Out:
# Mulai proses ekstraksi...

# %%
for i, item in enumerate(daftar_url, start=1):
    judul = item["judul"]
    url = item["url"]

    try:
        response = requests.get(
            url,
            headers=headers,
            timeout=30
        )

        if response.status_code == 200:
            html = response.text

            teks = trafilatura.extract(
                html,
                include_comments=False,
                include_tables=False
            )

            if teks:
                jumlah_kata = len(teks.split())

                hasil_data.append({
                    "id": i,
                    "judul": judul,
                    "url": url,
                    "teks": teks,
                    "jumlah_kata": jumlah_kata
                })

                print(f"{i}/200 berhasil: {judul}")
            else:
                print(f"{i}/200 teks tidak ditemukan: {judul}")

        else:
            print(f"{i}/200 gagal ({response.status_code}): {judul}")

        time.sleep(0.5)

    except Exception as e:
        print(f"{i}/200 error: {e}")
# Out:
# 1/200 berhasil: Teknologi
# 2/200 berhasil: Halaman Utama
# 3/200 berhasil: Sejarah teknologi
# 4/200 berhasil: Institut Teknologi Bandung
# 5/200 berhasil: YouTube
# 6/200 berhasil: Google
# 7/200 berhasil: Teknologi informasi komunikasi
# 8/200 berhasil: B. J. Habibie
# 9/200 berhasil: Kementerian Pendidikan Tinggi, Sains, dan Teknologi Republik Indonesia
# 10/200 berhasil: Teknologi informasi
# 11/200 berhasil: Teknologi finansial
# 12/200 berhasil: Sumatera Utara
# 13/200 berhasil: Yandex
# 14/200 berhasil: Kesehatan
# 15/200 berhasil: Teknologi pendidikan
# 16/200 berhasil: Informatika
# 17/200 berhasil: Teknologi olahraga
# 18/200 berhasil: Institut Teknologi Sepuluh Nopember
# 19/200 berhasil: Elang Mahkota Teknologi
# 20/200 berhasil: Tahap kesiapan teknologi
# 21/200 berhasil: Daerah Istimewa Yogyakarta
# 22/200 berhasil: Revolusi Digital
# 23/200 berhasil: Badan Pengkajian dan Penerapan Teknologi
# 24/200 berhasil: Universitas Teknologi Bandung
# 25/200 berhasil: Teknologi informasi Indonesia
# 26/200 berhasil: Luhut Binsar Pandjaitan
# 27/200 berhasil: Sains dan teknologi di Indonesia
# 28/200 berhasil: Daftar Menteri Riset dan Teknologi Indonesia
# 29/200 berhasil: Kecerdasan buatan
# 30/200 berhasil: Energi surya
# 31/200 berhasil: Kementerian Riset dan Teknologi Republik Indonesia
# 32/200 berhasil: Desa
# 33/200 berhasil: Balai Layanan Platform Teknologi
# 34/200 berhasil: Universitas Brawijaya
# 35/200 berhasil: Revolusi Industri
# 36/200 berhasil: Teknologi nuklir
# 37/200 berhasil: 5G
# 38/200 berhasil: Windows Vista
# 39/200 berhasil: Richardus Eko Indrajit
# 40/200 berhasil: Reini Wirahadikusumah
# 41/200 berhasil: Teknologi komunikasi digital
# 42/200 berhasil: Yassierli
# 43/200 berhasil: Teknologi dan masyarakat
# 44/200 berhasil: Teknologi kesehatan
# 45/200 berhasil: Video
# 46/200 berhasil: Telkomsel
# 47/200 berhasil: Universitas Indonesia
# 48/200 berhasil: Uni Soviet
# 49/200 berhasil: Perdagangan elektronik
# 50/200 berhasil: Teknologi nuklir di Indonesia
# 51/200 berhasil: Tap Talk Teknologi
# 52/200 berhasil: Honda PCX
# 53/200 berhasil: Universitas Gadjah Mada
# 54/200 berhasil: Brian Yuliarto
# 55/200 berhasil: Teknologi pertanian
# 56/200 berhasil: Teknologi seluler
# 194/200 berhasil: Institut Teknologi Padang
# 195/200 berhasil: Ilham Akbar Habibie
# 196/200 berhasil: Set-top box
# 197/200 berhasil: Magister
# 198/200 berhasil: Energi berkelanjutan
# 199/200 berhasil: Shenzhen
# 200/200 berhasil: MotoGP

# %%
df = pd.DataFrame(hasil_data)

print("Jumlah data berhasil:", len(df))
# Out:
# Jumlah data berhasil: 200

# %%
df = pd.DataFrame(hasil_data)

print("Jumlah data berhasil:", len(df))
# Out:
# Jumlah data berhasil: 200

# %%
df.head()
# Out:
#    id                       judul  \
# 0   1                   Teknologi
# 1   2               Halaman Utama
# 2   3           Sejarah teknologi
# 3   4  Institut Teknologi Bandung
# 4   5                     YouTube
#
#                                                  url  \
# 0            https://id.wikipedia.org/wiki/Teknologi
# 1        https://id.wikipedia.org/wiki/Halaman_Utama
# 2    https://id.wikipedia.org/wiki/Sejarah_teknologi
# 3  https://id.wikipedia.org/wiki/Institut_Teknolo...
# 4              https://id.wikipedia.org/wiki/YouTube
#
#                                                 teks  jumlah_kata
# 0  Teknologi\nTeknologi adalah penerapan pengetah...        10844
# 1  Halaman Utama\nArtikel pilihan\nArchaeopteryx ...          464
# 2  Sejarah teknologi\nSejarah teknologi mencakup ...         3259
# 3  Institut Teknologi Bandung\nInstitut Teknologi...         6661
# 4  YouTube\nYouTube adalah sebuah situs web berba...         9448

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           200 non-null    int64
#  1   judul        200 non-null    str
#  2   url          200 non-null    str
#  3   teks         200 non-null    str
#  4   jumlah_kata  200 non-null    int64
# dtypes: int64(2), str(3)
# memory usage: 7.9 KB

# %%
print("Jumlah baris:", len(df))
print("Jumlah kolom:", len(df.columns))
# Out:
# Jumlah baris: 200
# Jumlah kolom: 5

# %%
df["jumlah_kata"].describe()
# Out:
# count      200.000000
# mean      2508.250000
# std       2938.531837
# min        154.000000
# 25%        826.500000
# 50%       1407.500000
# 75%       2644.250000
# max      23678.000000
# Name: jumlah_kata, dtype: float64

# %%
df.sort_values(
    by="jumlah_kata",
    ascending=False
)[["judul", "jumlah_kata"]].head(10)
# Out:
#                                         judul  jumlah_kata
# 103                                Apple Inc.        23678
# 130                                      Ilmu        15424
# 0                                   Teknologi        10844
# 22   Badan Pengkajian dan Penerapan Teknologi        10721
# 176                               Rantai blok        10373
# 61                                 Generasi Z         9664
# 4                                     YouTube         9448
# 168                                 Smartfren         9398
# 14                       Teknologi pendidikan         8740
# 152            Universitas Jenderal Soedirman         8662

# %%
df.sort_values(
    by="jumlah_kata",
    ascending=True
)[["judul", "jumlah_kata"]].head(10)
# Out:
#                           judul  jumlah_kata
# 97    Revolusi Industri Keempat          154
# 122        Perusahaan teknologi          164
# 43          Teknologi kesehatan          242
# 164          Teknologi industri          244
# 72             Teknologi tinggi          281
# 144                          1G          298
# 93   Lambang Tut Wuri Handayani          303
# 108    Institut Teknologi Garut          311
# 105             Zaman Informasi          347
# 175           Gelembung dot-com          367

# %%
df.to_csv(
    "data_200_wikipedia.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Dataset berhasil disimpan.")
# Out:
# Dataset berhasil disimpan.
